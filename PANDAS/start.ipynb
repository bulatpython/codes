# %%
import pandas as pd
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
pd.Series(["Апельсин", "Киви", "Мандарин", "Яблоко"], name='fruits')
# Out:
# 0    Апельсин
# 1        Киви
# 2    Мандарин
# 3      Яблоко
# Name: fruits, dtype: object

# %%
my_series = pd.Series(data=[5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd', 'e', 'f'])
display(my_series.iloc[1:5])
# Out:
# b    6
# c    7
# d    8
# e    9
# dtype: int64

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902],
})
countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
display(pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B']))
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
import pandas as pd

def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
    'income': income,
    'expenses': expenses
    })
    df.index = years
    return df
    
def get_profit(df, year):
    years = df.index
    if year in years:
        return df.loc[year, 'income'] - df.loc[year, 'expenses']
    return None
    

income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]

df = create_companyDF(income, expenses, years)
print(get_profit(df, 2008))
# Out:
# None

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
melb_data.describe(include=['object'])
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data['Type'].value_counts(normalize=True)
# Out:
# h    0.695803
# u    0.222165
# t    0.082032
# Name: Type, dtype: float64

# %%
print(12211 - 13580)
# Out:
# -1369

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
import pandas as pd
print(melb_data['Price'].mean())
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Out:
# 1075684.079455081
# Total income of real estate agencies: 1752934775.88

# %%
print(abs(melb_data['BuildingArea'].median()-melb_data['BuildingArea'].mean())/melb_data['BuildingArea'].median())
# Out:
# 0.10820612928676636

# %%
print(melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0])
print(melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0])

# %%
display(melb_data[(melb_data['BuildingArea']==0)]['Price'].min())
display(melb_data[melb_data['Date'] > '2015'])
# Out:
# 412500.0
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
display(melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['Date'] > '31-12-2015'))]['Price'].mean())
# Out:
# 665467.0422939068

# %%
display(melb_data[(melb_data['Type'] == 'h')]['Regionname'].mode())
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
student_data = pd.read_csv('data/students_performance.csv', sep=',')
display(student_data['writing score'])
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
print(student_data.iloc[155])
# Out:
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               70
# reading score                            89
# writing score                            88
# Name: 155, dtype: object

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
mask = student_data['math score'] == 0
display(student_data[mask].count())
# Out:
# gender                         1
# race/ethnicity                 1
# parental level of education    1
# lunch                          1
# test preparation course        1
# math score                     1
# reading score                  1
# writing score                  1
# dtype: int64

# %%
mask_1 = student_data['lunch'] == 'standard'
mask_2 = student_data['lunch'] == 'free/reduced'
mask_3 = student_data['parental level of education'] == "bachelor's degree"
print(student_data[mask_1]['math score'].mean(), student_data[mask_2]['math score'].mean())
num_rows = student_data.shape[0]
print(num_rows)
display(student_data[mask_3].shape[0]/num_rows)
# Out:
# 70.03410852713178 58.92112676056338
# 1000
# 0.118

# %%
mask_4 = student_data['race/ethnicity'] == "group A"
mask_5 = student_data['race/ethnicity'] == "group C"

display(student_data[mask_4]['writing score'].median() - student_data[mask_5]['writing score'].mean())
display(student_data)
# Out:
# -5.827586206896555
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
